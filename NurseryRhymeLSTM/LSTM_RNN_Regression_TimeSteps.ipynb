# %%
# LSTM for international airline passengers problem with time step regression framing
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
 dataX, dataY = [], []
 for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
 return np.array(dataX), np.array(dataY)
# fix random seed for reproducibility
tf.random.set_seed(7)
# load the dataset
dataframe = read_csv('airline.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2023-04-20 12:31:30.561609: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-04-20 12:31:30.561737: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/100
# 2023-04-20 12:31:31.007911: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-04-20 12:31:31.577843: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-04-20 12:31:31.692692: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-04-20 12:31:32.422427: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 92/92 - 3s - loss: 0.0367 - 3s/epoch - 28ms/step
# Epoch 2/100
# 92/92 - 0s - loss: 0.0150 - 467ms/epoch - 5ms/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0121 - 485ms/epoch - 5ms/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0108 - 482ms/epoch - 5ms/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0095 - 470ms/epoch - 5ms/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0084 - 481ms/epoch - 5ms/step
# Epoch 7/100
# 92/92 - 1s - loss: 0.0073 - 552ms/epoch - 6ms/step
# Epoch 8/100
# 92/92 - 1s - loss: 0.0064 - 518ms/epoch - 6ms/step
# Epoch 9/100
# 92/92 - 1s - loss: 0.0055 - 575ms/epoch - 6ms/step
# Epoch 10/100
# 92/92 - 1s - loss: 0.0050 - 529ms/epoch - 6ms/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0046 - 498ms/epoch - 5ms/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0044 - 493ms/epoch - 5ms/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.0043 - 490ms/epoch - 5ms/step
# Epoch 14/100
# 92/92 - 1s - loss: 0.0044 - 514ms/epoch - 6ms/step
# Epoch 15/100
# 92/92 - 1s - loss: 0.0042 - 511ms/epoch - 6ms/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0041 - 485ms/epoch - 5ms/step
# Epoch 17/100
# 92/92 - 0s - loss: 0.0041 - 488ms/epoch - 5ms/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0041 - 480ms/epoch - 5ms/step
# Epoch 19/100
# 92/92 - 1s - loss: 0.0040 - 535ms/epoch - 6ms/step
# Epoch 20/100
# 92/92 - 1s - loss: 0.0040 - 573ms/epoch - 6ms/step
# Epoch 21/100
# 92/92 - 1s - loss: 0.0040 - 502ms/epoch - 5ms/step
# Epoch 22/100
# 92/92 - 1s - loss: 0.0041 - 563ms/epoch - 6ms/step
# Epoch 23/100
# 92/92 - 1s - loss: 0.0039 - 542ms/epoch - 6ms/step
# Epoch 24/100
# 92/92 - 1s - loss: 0.0040 - 522ms/epoch - 6ms/step
# Epoch 25/100
# 92/92 - 1s - loss: 0.0040 - 548ms/epoch - 6ms/step
# Epoch 26/100
# 92/92 - 0s - loss: 0.0039 - 493ms/epoch - 5ms/step
# Epoch 27/100
# 92/92 - 1s - loss: 0.0039 - 513ms/epoch - 6ms/step
# Epoch 28/100
# 92/92 - 0s - loss: 0.0040 - 462ms/epoch - 5ms/step
# Epoch 29/100
# 92/92 - 0s - loss: 0.0039 - 465ms/epoch - 5ms/step
# Epoch 30/100
# 92/92 - 0s - loss: 0.0038 - 467ms/epoch - 5ms/step
# Epoch 31/100
# 92/92 - 1s - loss: 0.0040 - 501ms/epoch - 5ms/step
# Epoch 32/100
# 92/92 - 0s - loss: 0.0039 - 471ms/epoch - 5ms/step
# Epoch 33/100
# 92/92 - 0s - loss: 0.0039 - 467ms/epoch - 5ms/step
# Epoch 34/100
# 92/92 - 0s - loss: 0.0039 - 471ms/epoch - 5ms/step
# Epoch 35/100
# 92/92 - 0s - loss: 0.0039 - 491ms/epoch - 5ms/step
# Epoch 36/100
# 92/92 - 0s - loss: 0.0039 - 466ms/epoch - 5ms/step
# Epoch 37/100
# 92/92 - 0s - loss: 0.0037 - 484ms/epoch - 5ms/step
# Epoch 38/100
# 92/92 - 0s - loss: 0.0036 - 481ms/epoch - 5ms/step
# Epoch 39/100
# 92/92 - 0s - loss: 0.0037 - 467ms/epoch - 5ms/step
# Epoch 40/100
# 92/92 - 0s - loss: 0.0037 - 479ms/epoch - 5ms/step
# Epoch 41/100
# 92/92 - 0s - loss: 0.0037 - 457ms/epoch - 5ms/step
# Epoch 42/100
# 92/92 - 0s - loss: 0.0037 - 456ms/epoch - 5ms/step
# Epoch 43/100
# 92/92 - 0s - loss: 0.0037 - 460ms/epoch - 5ms/step
# Epoch 44/100
# 92/92 - 0s - loss: 0.0037 - 468ms/epoch - 5ms/step
# Epoch 45/100
# 92/92 - 0s - loss: 0.0036 - 465ms/epoch - 5ms/step
# Epoch 46/100
# 92/92 - 0s - loss: 0.0036 - 464ms/epoch - 5ms/step
# Epoch 47/100
# 92/92 - 0s - loss: 0.0036 - 476ms/epoch - 5ms/step
# Epoch 48/100
# 92/92 - 0s - loss: 0.0035 - 466ms/epoch - 5ms/step
# Epoch 49/100
# 92/92 - 0s - loss: 0.0035 - 462ms/epoch - 5ms/step
# Epoch 50/100
# 92/92 - 0s - loss: 0.0034 - 464ms/epoch - 5ms/step
# Epoch 51/100
# 92/92 - 0s - loss: 0.0035 - 460ms/epoch - 5ms/step
# Epoch 52/100
# 92/92 - 0s - loss: 0.0034 - 467ms/epoch - 5ms/step
# Epoch 53/100
# 92/92 - 0s - loss: 0.0033 - 464ms/epoch - 5ms/step
# Epoch 54/100
# 92/92 - 0s - loss: 0.0035 - 487ms/epoch - 5ms/step
# Epoch 55/100
# 92/92 - 0s - loss: 0.0035 - 483ms/epoch - 5ms/step
# Epoch 56/100
# 92/92 - 0s - loss: 0.0035 - 462ms/epoch - 5ms/step
# Epoch 57/100
# 92/92 - 0s - loss: 0.0035 - 467ms/epoch - 5ms/step
# Epoch 58/100
# 92/92 - 0s - loss: 0.0033 - 468ms/epoch - 5ms/step
# Epoch 59/100
# 92/92 - 0s - loss: 0.0034 - 462ms/epoch - 5ms/step
# Epoch 60/100
# 92/92 - 0s - loss: 0.0034 - 464ms/epoch - 5ms/step
# Epoch 61/100
# 92/92 - 0s - loss: 0.0034 - 467ms/epoch - 5ms/step
# Epoch 62/100
# 92/92 - 0s - loss: 0.0034 - 465ms/epoch - 5ms/step
# Epoch 63/100
# 92/92 - 1s - loss: 0.0033 - 506ms/epoch - 5ms/step
# Epoch 64/100
# 92/92 - 1s - loss: 0.0032 - 552ms/epoch - 6ms/step
# Epoch 65/100
# 92/92 - 1s - loss: 0.0032 - 524ms/epoch - 6ms/step
# Epoch 66/100
# 92/92 - 1s - loss: 0.0032 - 588ms/epoch - 6ms/step
# Epoch 67/100
# 92/92 - 1s - loss: 0.0032 - 553ms/epoch - 6ms/step
# Epoch 68/100
# 92/92 - 1s - loss: 0.0031 - 547ms/epoch - 6ms/step
# Epoch 69/100
# 92/92 - 1s - loss: 0.0030 - 531ms/epoch - 6ms/step
# Epoch 70/100
# 92/92 - 1s - loss: 0.0030 - 523ms/epoch - 6ms/step
# Epoch 71/100
# 92/92 - 1s - loss: 0.0032 - 515ms/epoch - 6ms/step
# Epoch 72/100
# 92/92 - 0s - loss: 0.0030 - 498ms/epoch - 5ms/step
# Epoch 73/100
# 92/92 - 0s - loss: 0.0030 - 470ms/epoch - 5ms/step
# Epoch 74/100
# 92/92 - 0s - loss: 0.0030 - 488ms/epoch - 5ms/step
# Epoch 75/100
# 92/92 - 1s - loss: 0.0028 - 523ms/epoch - 6ms/step
# Epoch 76/100
# 92/92 - 1s - loss: 0.0028 - 602ms/epoch - 7ms/step
# Epoch 77/100
# 92/92 - 1s - loss: 0.0028 - 554ms/epoch - 6ms/step
# Epoch 78/100
# 92/92 - 1s - loss: 0.0028 - 524ms/epoch - 6ms/step
# Epoch 79/100
# 92/92 - 0s - loss: 0.0028 - 483ms/epoch - 5ms/step
# Epoch 80/100
# 92/92 - 0s - loss: 0.0026 - 456ms/epoch - 5ms/step
# Epoch 81/100
# 92/92 - 0s - loss: 0.0027 - 489ms/epoch - 5ms/step
# Epoch 82/100
# 92/92 - 0s - loss: 0.0027 - 480ms/epoch - 5ms/step
# Epoch 83/100
# 92/92 - 1s - loss: 0.0026 - 503ms/epoch - 5ms/step
# Epoch 84/100
# 92/92 - 0s - loss: 0.0026 - 490ms/epoch - 5ms/step
# Epoch 85/100
# 92/92 - 0s - loss: 0.0026 - 470ms/epoch - 5ms/step
# Epoch 86/100
# 92/92 - 1s - loss: 0.0025 - 531ms/epoch - 6ms/step
# Epoch 87/100
# 92/92 - 0s - loss: 0.0026 - 489ms/epoch - 5ms/step
# Epoch 88/100
# 92/92 - 1s - loss: 0.0024 - 509ms/epoch - 6ms/step
# Epoch 89/100
# 92/92 - 1s - loss: 0.0024 - 514ms/epoch - 6ms/step
# Epoch 90/100
# 92/92 - 0s - loss: 0.0024 - 461ms/epoch - 5ms/step
# Epoch 91/100
# 92/92 - 1s - loss: 0.0024 - 526ms/epoch - 6ms/step
# Epoch 92/100
# 92/92 - 1s - loss: 0.0025 - 533ms/epoch - 6ms/step
# Epoch 93/100
# 92/92 - 0s - loss: 0.0024 - 497ms/epoch - 5ms/step
# Epoch 94/100
# 92/92 - 0s - loss: 0.0024 - 463ms/epoch - 5ms/step
# Epoch 95/100
# 92/92 - 0s - loss: 0.0023 - 462ms/epoch - 5ms/step
# Epoch 96/100
# 92/92 - 0s - loss: 0.0023 - 462ms/epoch - 5ms/step
# Epoch 97/100
# 92/92 - 0s - loss: 0.0024 - 461ms/epoch - 5ms/step
# Epoch 98/100
# 92/92 - 0s - loss: 0.0022 - 467ms/epoch - 5ms/step
# Epoch 99/100
# 92/92 - 0s - loss: 0.0022 - 477ms/epoch - 5ms/step
# Epoch 100/100
# 92/92 - 0s - loss: 0.0021 - 459ms/epoch - 5ms/step
# 2023-04-20 12:32:22.799983: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-04-20 12:32:22.849755: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 1s 11ms/step
# 2/2 [==============================] - 0s 79ms/step
# Train Score: 24.84 RMSE
# Test Score: 60.98 RMSE
